# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
positive_reviews = ["Позитивна рецензія 1", "Позитивна рецензія 2"]
negative_reviews = ["Негативна рецензія 1", "Негативна рецензія 2"]

reviews = positive_reviews + negative_reviews

tokenizer = Tokenizer()
tokenizer.fit_on_texts(reviews)
total_words = len(tokenizer.word_index) + 1

input_sequences = tokenizer.texts_to_sequences(reviews)
max_sequence_length = max([len(x) for x in input_sequences])
padded_sequences = pad_sequences(input_sequences, maxlen=max_sequence_length, padding='pre')

X_train = padded_sequences[:2]
y_train = np.array([1, 1])
X_test = padded_sequences[2:]
y_test = np.array([0, 0])

# Створення моделі GRU
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(total_words, 64, input_length=max_sequence_length),
    tf.keras.layers.GRU(64),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 1/1 [==============================] - 4s 4s/step - loss: 0.6949 - accuracy: 0.5000 - val_loss: 0.7025 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6814 - accuracy: 1.0000 - val_loss: 0.7148 - val_accuracy: 0.0000e+00
# Epoch 3/10
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6681 - accuracy: 1.0000 - val_loss: 0.7273 - val_accuracy: 0.0000e+00
# Epoch 4/10
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6548 - accuracy: 1.0000 - val_loss: 0.7401 - val_accuracy: 0.0000e+00
# Epoch 5/10
# 1/1 [==============================] - 0s 40ms/step - loss: 0.6415 - accuracy: 1.0000 - val_loss: 0.7534 - val_accuracy: 0.0000e+00
# Epoch 6/10
# 1/1 [==============================] - 0s 46ms/step - loss: 0.6279 - accuracy: 1.0000 - val_loss: 0.7672 - val_accuracy: 0.0000e+00
# Epoch 7/10
# 1/1 [==============================] - 0s 42ms/step - loss: 0.6141 - accuracy: 1.0000 - val_loss: 0.7817 - val_accuracy: 0.0000e+00
# Epoch 8/10
# 1/1 [==============================] - 0s 40ms/step - loss: 0.6000 - accuracy: 1.0000 - val_loss: 0.7971 - val_accuracy: 0.0000e+00
# Epoch 9/10
# 1/1 [==============================] - 0s 39ms/step - loss: 0.5854 - accuracy: 1.0000 - val_loss: 0.8133 - val_accuracy: 0.0000e+00
# Epoch 10/10
# 1/1 [==============================] - 0s 42ms/step - loss: 0.5702 - accuracy: 1.0000 - val_loss: 0.8306 - val_accuracy: 0.0000e+00
